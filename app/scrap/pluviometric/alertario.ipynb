# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select

from webdriver_manager.firefox import GeckoDriverManager

import os
os.chdir("/home/gabriel/Desktop/datalake") 

from app.config.selenium_config import SeleniumConfig

# %%
selenium_cfg = SeleniumConfig(
    headless=False, 
)

driver = selenium_cfg.create_driver()

# %%
driver.get("http://websempre.rio.rj.gov.br/dados/pluviometricos/plv/")

# %%
# Seleciona todas as estações pluviométricas
driver.find_element(By.XPATH, "/html/body/div/form/table/tbody/tr[34]/td[3]").click()

# %%
# Baixar os arquivos de cada estação
driver.find_element(
    By.XPATH, "//input[@type='submit' and @value='Download']"
).click()

# %%
os.curdir
# Out:
# '.'

# %%
# Mudar o ano para todas as seleções
select_element = Select(
    driver.find_element(By.ID, "all_choice")
)

select_element.select_by_value("2018")

# %%
driver.quit()
